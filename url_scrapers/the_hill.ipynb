# %%
#Import necessary libraries
import time
import requests
import urllib
import lxml.html
from bs4 import BeautifulSoup
import newspaper
import trafilatura
from datetime import datetime
import re

# %%
politics_sections = ["senate","house","administration","campaign","elections"]

# %%
def obtain_page_urls(section="senate",page="1"):
    """
    Obtain the urls for a page of results from the politics section of Breitbart
    Inputs:
    -page(str): page of results to search in results
    Return:
    links_list(list): List of urls 
    """
    url = "https://thehill.com/homenews/{}/?page_num={}".format(section,page)
    resp = requests.get(url)
    root = lxml.html.fromstring(resp.text)
    articles_elements = root.cssselect("div.archive__item__content")
    links_list = []
    for article in articles_elements:
        url = article.cssselect("a")[0].get("href")
        #full_link = "breitbart.com" + str(url)
        links_list.append(url)
    
    return links_list

obtain_page_urls()
# Out:
# ['',
#  'https://thehill.com/homenews/senate/4089401-mcconnell-takes-aim-at-schumer-biden-for-escalating-attacks-on-supreme-court/',
#  'https://thehill.com/homenews/senate/4089170-senators-to-receive-first-ever-classified-briefing-on-artificial-intelligence/',
#  'https://thehill.com/regulation/court-battles/4088549-left-leaning-advocacy-coalition-calls-on-congress-to-investigate-supreme-court-ethics/',
#  'https://thehill.com/policy/healthcare/4088519-schumer-calls-for-investigation-into-prime-energy-drink-created-by-youtube-stars-logan-paul-ksi/',
#  'https://thehill.com/homenews/house/4088125-house-gop-gets-set-to-grill-fbi-director/',
#  'https://thehill.com/homenews/senate/4087830-schumer-calls-out-thomas-alito-for-accepting-lavish-gifts-and-vacations-from-billionaires/',
#  'https://thehill.com/homenews/senate/4087700-schumer-puts-insulin-prescription-drug-reform-supreme-court-ethics-on-july-agenda/',
# ...

# %%
def obtain_section_url(section="senate",max_pages_to_crawl=1000):
    """ 
    
    """
    links_dict = {}
    links_list = []
    for page in range(1,max_pages_to_crawl+1):
        print("Page:",page)
        page_urls = obtain_page_urls(section,page)
        links_list.extend(page_urls)
    links_set = set(links_list)
    print("Len set",len(links_set))
    print("Len list",len(links_list))
    
    return links_list

obtain_section_url("senate",1000)
# Out:
# Page: 1
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# Page: 10
# Page: 11
# Page: 12
# Page: 13
# Page: 14
# Page: 15
# Page: 16
# Page: 17
# Page: 18
# Page: 19
# Page: 20
# Page: 21
# Page: 22
# Page: 23
# Page: 24
# Page: 25
# Page: 26
# Page: 27
# Page: 28
# Page: 29
# Page: 30
# Page: 31
# Page: 32
# Page: 33
# Page: 34
# Page: 35
# Page: 36
# Page: 37
# Page: 38
# Page: 39
# Page: 40
# Page: 41
# Page: 42
# Page: 43
# Page: 44
# Page: 45
# Page: 46
# Page: 47
# Page: 48
# Page: 49
# Page: 50
# Page: 51
# Page: 52
# Page: 53
# Page: 54
# Page: 55
# Page: 56
# Page: 57
# Page: 58
# Page: 59
# Page: 60
# Page: 61
# Page: 62
# Page: 63
# Page: 64
# Page: 65
# Page: 66
# Page: 67
# Page: 68
# Page: 69
# Page: 70
# Page: 71
# Page: 72
# Page: 73
# Page: 74
# Page: 75
# Page: 76
# Page: 77
# Page: 78
# Page: 79
# Page: 80
# Page: 81
# Page: 82
# Page: 83
# Page: 84
# Page: 85
# Page: 86
# Page: 87
# Page: 88
# Page: 89
# Page: 90
# Page: 91
# ...
