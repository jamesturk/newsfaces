# %%
#Util Functions
import time
import requests
from urllib.parse import urlparse
import sys
import json
import lxml.html
import csv
from utils import make_request, parse_html, make_link_absolute, page_grab

# %%
def get_urls(url):
    """
    This function takes a URL to a page of articles and returns all
    of the articles
    

    Parameters:
        * url:  a URL to a page of parks

    Returns:
        A list of URLs to each park on the page.
    """
    response= page_grab(url)
    urls=[]
    container = response.cssselect('div.archive__item__content')
    
    for j in container:
        atr = j.cssselect('a')
        if atr and len(atr) > 0:
            href = atr[0].get("href")
            urls.append(make_link_absolute(href, 'https://www.politico.com'))
    return urls

get_urls('https://thehill.com/policy/?page_num=1064')
# Out:
# Fetching https://thehill.com/policy/?page_num=1064
# ['',
#  'https://thehill.com/homenews/administration/450388-trump-says-google-facebook-should-be-sued-over-bias-allegations/',
#  'https://thehill.com/homenews/administration/450382-trump-criticizes-post-world-war-ii-military-pact-with-japan/',
#  'https://thehill.com/blogs/blog-briefing-room/news/450371-2-us-service-members-killed-in-afghanistan/',
#  'https://thehill.com/homenews/house/450215-house-passes-45b-border-funding-bill/',
#  'https://thehill.com/homenews/house/450358-mueller-to-testify-in-front-of-house-judiciary-intelligence-committees-next/',
#  'https://thehill.com/blogs/floor-action/senate/450334-senate-gop-blocks-election-security-bill/',
#  'https://thehill.com/policy/technology/overnights/450304-hillicon-valley-report-finds-federal-agencies-failed-to-update/',
#  'https://thehill.com/homenews/campaign/450323-150-young-activists-to-camp-out-at-dnc-for-climate-debate/',
#  'https://thehill.com/regulation/court-battles/450319-doj-files-federal-lawsuit-against-omarosa-alleging-she-violated/',
#  'https://thehill.com/homenews/senate/450285-mcconnell-opens-door-to-vote-on-iran-war-authorization/',
#  'https://thehill.com/policy/finance/economy/450278-gm-investing-4b-in-plants-in-four-states/',
#  'https://thehill.com/homenews/media/450275-florida-news-outlets-partnering-for-climate-change-reporting/',
#  'https://thehill.com/latino/450276-trump-envoy-protected-status-for-venezuelan-migrants-under-consideration/',
#  'https://thehill.com/homenews/state-watch/450268-democratic-leader-concedes-on-oregon-climate-bill-after-republican/',
#  'https://thehill.com/homenews/house/450251-house-approves-383-billion-spending-package/',
#  'https://thehill.com/homenews/administration/450245-trump-says-migrant-detention-conditions-better-than-they-were-under/']

# %%
def recurse_hill(url, breakpoint, urls=[]):
     scraped_urls=get_urls(url)
     urls+= scraped_urls
     begin=url.find("num=")+4
     pagenumber= int(url[begin:len(url)])
     if pagenumber<breakpoint:
          newlink=url[:-len(str(pagenumber))]+str(pagenumber+1)
          recurse_hill(newlink, breakpoint, urls)
     return urls

def list_to_csv(data_list, filename):
    print("writing csv")
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        for item in data_list:
            writer.writerow([item])

# %%
urllist=recurse_hill('https://thehill.com/policy/?page_num=1', 1064)
list_to_csv(urllist, "thehill.csv")
# Out:
# Fetching https://thehill.com/policy/?page_num=1
# Fetching https://thehill.com/policy/?page_num=2
# Fetching https://thehill.com/policy/?page_num=3
# Fetching https://thehill.com/policy/?page_num=4
# Fetching https://thehill.com/policy/?page_num=5
# Fetching https://thehill.com/policy/?page_num=6
# Fetching https://thehill.com/policy/?page_num=7
# Fetching https://thehill.com/policy/?page_num=75
# Fetching https://thehill.com/policy/?page_num=76
# Fetching https://thehill.com/policy/?page_num=77
# Fetching https://thehill.com/policy/?page_num=78
# Fetching https://thehill.com/policy/?page_num=79
# Fetching https://thehill.com/policy/?page_num=80
# Fetching https://thehill.com/policy/?page_num=81
# Fetching https://thehill.com/policy/?page_num=82
# Fetching https://thehill.com/policy/?page_num=83
# Fetching https://thehill.com/policy/?page_num=84
# Fetching https://thehill.com/policy/?page_num=85
# Fetching https://thehill.com/policy/?page_num=86
# Fetching https://thehill.com/policy/?page_num=87
# Fetching https://thehill.com/policy/?page_num=88
# Fetching https://thehill.com/policy/?page_num=89
# Fetching https://thehill.com/policy/?page_num=90
# Fetching https://thehill.com/policy/?page_num=91
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 urllist=recurse_hill('https://thehill.com/policy/?page_num=1', 1064)
#       2 list_to_csv(urllist, "thehill.csv")
#
# Cell In[16], line 8, in recurse_hill(url, breakpoint, urls)
#       6 if pagenumber<breakpoint:
#       7      newlink=url[:-len(str(pagenumber))]+str(pagenumber+1)
# ----> 8      recurse_hill(newlink, breakpoint, urls)
#       9 return urls
#
# Cell In[16], line 8, in recurse_hill(url, breakpoint, urls)
#       6 if pagenumber<breakpoint:
#       7      newlink=url[:-len(str(pagenumber))]+str(pagenumber+1)
# ----> 8      recurse_hill(newlink, breakpoint, urls)
#       9 return urls
#
#     [... skipping similar frames: recurse_hill at line 8 (87 times)]
#
# Cell In[16], line 8, in recurse_hill(url, breakpoint, urls)
#       6 if pagenumber<breakpoint:
#       7      newlink=url[:-len(str(pagenumber))]+str(pagenumber+1)
# ----> 8      recurse_hill(newlink, breakpoint, urls)
#       9 return urls
#
# Cell In[16], line 2, in recurse_hill(url, breakpoint, urls)
#       1 def recurse_hill(url, breakpoint, urls=[]):
# ----> 2      scraped_urls=get_urls(url)
#       3      urls+= scraped_urls
#       4      begin=url.find("num=")+4
#
# Cell In[15], line 13, in get_urls(url)
#       1 def get_urls(url):
#       2     """
#       3     This function takes a URL to a page of articles and returns all
#       4     of the articles
#    (...)
#      11         A list of URLs to each park on the page.
#      12     """
# ---> 13     response= page_grab(url)
#      14     urls=[]
#      15     container = response.cssselect('div.archive__item__content')
#
# File ~/newsfaces/src/newsfaces/utils.py:60, in page_grab(url, session)
#      59 def page_grab(url, session=None):
# ---> 60     response = make_request(url, session)
#      61     root = parse_html(response.text)
#      62     return root
#
# File ~/newsfaces/src/newsfaces/utils.py:26, in make_request(url, session)
#      24     resp = session.get(url)
#      25 else:
# ---> 26     resp = requests.get(url)
#      27 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
